# %% [markdown]
# <h1>作業一</h1>
# data: Chicago Crime
# <br>
# <br>
# <br>
# <li>Q1 你選的這組資料為何重要？：</li>
# <ul>資料於2001年紀錄至2017年期間，統計哪些類別的犯罪率同比增幅最大？哪個月的汽車盜竊案一般最多？溫度如何影響暴力犯罪的事故發生率？</ul>
# <li>Q2 資料從何而？：</li>
# <ul>Kaggle - DataSet</ul>
# <ul>https://www.kaggle.com/chicago/chicago-crime</ul>
# <li>Q3 蒐集而來的資料型態為何？：</li>
# <ul>Date, String, int, float</ul>
# <li>Q4 這組資料想解決的問題如何評估？：</li>
# <ul>Maby 回歸分析</ul>
#
# <br>
# <br>
# <br>
# <h1>作業二</h1>
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# <br>
# <br>
# <br>
# <li>Q1 核心問題為何？：</li>
# <ul>1. 駕駛使用語言</ul>
# <ul>2. 車輛整潔程度，以每週清潔次數，每月花費保養費用</ul>
# <ul>3. 駕駛服務</ul>
# <ul>4. 車輛型號</ul>
# <ul>5. 該趟出車平均速率</ul>
# <ul>6. 載客區域與時段</ul>
# <li>Q2 資料從何而來？：</li>
# <ul>1. 駕駛基本資料</ul>
# <ul>2. 駕駛回報</ul>
# <ul>3. 客戶反饋</ul>
# <ul>4. 駕駛基本資料</ul>
# <ul>5. 駕駛回報</ul>
# <ul>6. 駕駛回報</ul>
# <li>Q3 蒐集而來的資料型態為何？：</li>
# <ul>1. varchar</ul>
# <ul>2. int</ul>
# <ul>3. text</ul>
# <ul>4. varchar</ul>
# <ul>5. float</ul>
# <ul>6. varchar, datetime</ul>
# <li>Q4 你要回答的問題，其如何評估？：</li>
# <ul>觀察各種型號車輛、清潔分數、行車速率與駕駛精通語言對於客戶滿意度之程度</ul>
# <ul>觀察何時段、區域與業績成長或下降之程度</ul>
#
# <br>
# <br>
# <br>
# <h1>作業三</h1>
# 請寫一個函式用來計算 Mean Square Error
# <br>
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    square_error = (y - y_hat) ** 2
    return sum(square_error) / len(y)

# %%
def mean_absolute_error(y, y_hat):
    absolute_error = abs(y - y_hat)
    return sum(absolute_error) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 203.987
# The Mean absolute error is 11.668
